# %% [markdown]
# The following notebook contains the code for computing the Trajectory Rotation Average ($ \mathrm{\overline{TRA}} $) for drifters within the Grand LAgrangian Deployment (GLAD) dataset.

# %% [markdown]
# # Import data

# %% [markdown]
# ## Import GLAD drifter data

# %%
# %%time
import numpy as np
from datetime import datetime

# get parent directory of working directory
import os
parentdirectory = os.path.dirname(os.getcwd())

# Import pandas
import pandas as pd

# get data directory where preprocesed GDP drifter data is stored.
# All the GDP drifters which were continuously active from the 04/10/2006 to the 10/10/2006 are stored in this directory.
data_directory = parentdirectory+"/data/GLAD/Drifter_processed"

drifters = []

for r, d, f in os.walk(data_directory):
    # r=root, d=directories, f = files
    for file in f:
        if file.endswith(".csv"):
            csv_file = pd.read_csv(r+"/"+file).values
            time_string = csv_file[:,0]
            time_datetime = [datetime.strptime(s, '%Y-%m-%d %H:%M:%S') for s in time_string]
            time_seconds = [0]
            for i in range(len(time_datetime)-1):
                time_seconds.append(int((time_datetime[i+1]-time_datetime[0]).total_seconds()))
            longitude = csv_file[:,1]
            latitude = csv_file[:,2]
            drifters.append([time_seconds, longitude, latitude])
# Out:
# CPU times: user 2 s, sys: 79.9 ms, total: 2.08 s
# Wall time: 2.08 s

# %% [markdown]
# ## Import Bathymetry data

# %%
from netCDF4 import Dataset, num2date
import great_circle_calculator.great_circle_calculator as gcc
import numpy as np

def import_bathymetry(nc_file):

    fileobj = Dataset(nc_file, 'r')
    # only extract bathymetry levels in the region of interest (=GOM)
    long = fileobj.variables['lon'][21500:23100]
    lat = fileobj.variables['lat'][27300:30000]
    bath = fileobj.variables['elevation'][27300:30000, 21500:23100]
    X, Y = np.meshgrid(long, lat)
    return X[:-1235, 250:-580], Y[:-1235, 250:-580], bath[:-1235, 250:-580]

x_bath, y_bath, bath = import_bathymetry(parentdirectory + "/data/Bathymetry/GEBCO_2020.nc")

# %% [markdown]
# # Compute $ \mathrm{\overline{TRA}} $

# %%
# %%time
from ipynb.fs.defs.TRA import __TRA__

# Define characteristic velocity
v0 = 10**(-5)

TRA, long, lat = [], [], []
long_final, lat_final = [], []

# iterate over all drifters:
for d in drifters:
    # time
    time = d[0]
    #longitudinal position of drifter d
    longitude = d[1]
    # latitudinal position of drifter d
    latitude = d[2]
    # TRA associated to drifter d over the time d[0]
    f = 96
    TRA.append(__TRA__(longitude, latitude, time, f))
    # Append longitude/latitude
    long.append(longitude)
    lat.append(latitude)
    # store final position
    long_final.append(longitude[-1])
    lat_final.append(latitude[-1])
# Out:
# CPU times: user 2.92 s, sys: 48.9 ms, total: 2.97 s
# Wall time: 2.97 s

# %% [markdown]
# # Interpolate data from scattered grid to regular meshgrid using rbf-interpolation

# %%
from metpy.interpolate import interpolate_to_grid

# linear rbf interpolation
def rbf(x, y, TRA, resolution):
    X, Y, interp = interpolate_to_grid(x, y, TRA, interp_type='rbf', rbf_func = 'linear', rbf_smooth = 0.000001, hres=resolution)
    return X, Y, interp

# resolution of scattered interpolation
res_interpolation = 0.01

# scattered linear rbf-interpolation
X, Y, TRA_rbf = rbf(long_final, lat_final, TRA, res_interpolation)

# %% [markdown]
# # Plot results

# %% [markdown]
# ##### Define colormapping equivalent to MATLAB 'parula' (This is a hidden cell as it does not influence the computations)

# %%
# Define colormapping 'parula'
from matplotlib.colors import LinearSegmentedColormap
cm_data = [[0.2422, 0.1504, 0.6603],
[0.2444, 0.1534, 0.6728],
[0.2464, 0.1569, 0.6847],
[0.2484, 0.1607, 0.6961],
[0.2503, 0.1648, 0.7071],
[0.2522, 0.1689, 0.7179],
[0.254, 0.1732, 0.7286],
[0.2558, 0.1773, 0.7393],
[0.2576, 0.1814, 0.7501],
[0.2594, 0.1854, 0.761],
[0.2611, 0.1893, 0.7719],
[0.2628, 0.1932, 0.7828],
[0.2645, 0.1972, 0.7937],
[0.2661, 0.2011, 0.8043],
[0.2676, 0.2052, 0.8148],
[0.2691, 0.2094, 0.8249],
[0.2704, 0.2138, 0.8346],
[0.2717, 0.2184, 0.8439],
[0.2729, 0.2231, 0.8528],
[0.274, 0.228, 0.8612],
[0.2749, 0.233, 0.8692],
[0.2758, 0.2382, 0.8767],
[0.2766, 0.2435, 0.884],
[0.2774, 0.2489, 0.8908],
[0.2781, 0.2543, 0.8973],
[0.2788, 0.2598, 0.9035],
[0.2794, 0.2653, 0.9094],
[0.2798, 0.2708, 0.915],
[0.2802, 0.2764, 0.9204],
[0.2806, 0.2819, 0.9255],
[0.2809, 0.2875, 0.9305],
[0.2811, 0.293, 0.9352],
[0.2813, 0.2985, 0.9397],
[0.2814, 0.304, 0.9441],
[0.2814, 0.3095, 0.9483],
[0.2813, 0.315, 0.9524],
[0.2811, 0.3204, 0.9563],
[0.2809, 0.3259, 0.96],
[0.2807, 0.3313, 0.9636],
[0.2803, 0.3367, 0.967],
[0.2798, 0.3421, 0.9702],
[0.2791, 0.3475, 0.9733],
[0.2784, 0.3529, 0.9763],
[0.2776, 0.3583, 0.9791],
[0.2766, 0.3638, 0.9817],
[0.2754, 0.3693, 0.984],
[0.2741, 0.3748, 0.9862],
[0.2726, 0.3804, 0.9881],
[0.271, 0.386, 0.9898],
[0.2691, 0.3916, 0.9912],
[0.267, 0.3973, 0.9924],
[0.2647, 0.403, 0.9935],
[0.2621, 0.4088, 0.9946],
[0.2591, 0.4145, 0.9955],
[0.2556, 0.4203, 0.9965],
[0.2517, 0.4261, 0.9974],
[0.2473, 0.4319, 0.9983],
[0.2424, 0.4378, 0.9991],
[0.2369, 0.4437, 0.9996],
[0.2311, 0.4497, 0.9995],
[0.225, 0.4559, 0.9985],
[0.2189, 0.462, 0.9968],
[0.2128, 0.4682, 0.9948],
[0.2066, 0.4743, 0.9926],
[0.2006, 0.4803, 0.9906],
[0.195, 0.4861, 0.9887],
[0.1903, 0.4919, 0.9867],
[0.1869, 0.4975, 0.9844],
[0.1847, 0.503, 0.9819],
[0.1831, 0.5084, 0.9793],
[0.1818, 0.5138, 0.9766],
[0.1806, 0.5191, 0.9738],
[0.1795, 0.5244, 0.9709],
[0.1785, 0.5296, 0.9677],
[0.9634, 0.8778, 0.1582],
[0.9619, 0.884, 0.1557],
[0.9608, 0.8902, 0.1532],
[0.9601, 0.8963, 0.1507],
[0.9596, 0.9023, 0.148],
[0.9595, 0.9084, 0.145],
[0.9597, 0.9143, 0.1418],
[0.9601, 0.9203, 0.1382],
[0.9608, 0.9262, 0.1344],
[0.9618, 0.932, 0.1304],
[0.9629, 0.9379, 0.1261],
[0.9642, 0.9437, 0.1216],
[0.9657, 0.9494, 0.1168],
[0.9674, 0.9552, 0.1116],
[0.9692, 0.9609, 0.1061],
[0.9711, 0.9667, 0.1001],
[0.973, 0.9724, 0.0938],
[0.9749, 0.9782, 0.0872],
[0.9769, 0.9839, 0.0805]]

# parula_map
parula_map = LinearSegmentedColormap.from_list('parula', cm_data)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# suppress deprecation warning from cartopy library
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import numpy as np

fig = plt.figure(figsize=(10, 7), constrained_layout=True)
ax = plt.axes(projection=ccrs.PlateCarree())#PlateCarree
ax.natural_earth_shp(name='land', resolution='10m', category='physical', facecolor = "grey")
ax.coastlines(resolution = "10m", edgecolor = "k")
ax.set_ylabel("Latitude (°)", fontsize = 16)
ax.set_xlabel("Longitude (°)", fontsize = 16)

x_limits = [-89.5, -86]
y_limits = [26.5, 29.5]

x_min = -89.5
x_max = -86
y_min = 26.5
y_max = 29.5

# Set ticks and limits
ax.set_xticks(np.arange(x_min, x_max + 0.5, 0.5))
ax.set_yticks(np.arange(y_min, y_max + 0.5, 0.5))
ax.set_ylim([y_min, y_max])
ax.set_xlim([x_min, x_max])

# Plot bathymetry levels
bath_levels = np.flip([-50, -100, -400, -800, -1200, -2000])
contour_bath = ax.contour(x_bath, y_bath, bath, levels=bath_levels, colors='black', transform=ccrs.PlateCarree())
cb = ax.clabel(contour_bath, inline=True, inline_spacing=5, fontsize=10, fmt="%0.f")

cax = ax.contourf(X, Y, TRA_rbf, levels = 600, cmap = parula_map, zorder = -1, transform=ccrs.PlateCarree())

ax.scatter(long_final, lat_final, s=40, marker="^", linewidth=1, edgecolor='k', facecolor='None', transform=ccrs.PlateCarree())
                
# Define limits
ax.set_xlim([-89.5, -86])
ax.set_ylim([26.5, 29.5])

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="2%", pad=0.05, axes_class=plt.Axes)

fig.add_axes(ax_cb)

# cbar TRA
cbar_ticks = [.3, .5, .7, .9, 1.1, 1.3, 1.5, 1.7]
cbar = plt.colorbar(cax, ax_cb, ticks = cbar_ticks, orientation="vertical")
cbar.ax.set_ylabel(r'$\mathrm{\overline{TRA}_{222}^{229}} (\dfrac{rad}{d}) $', rotation=0, y = 0.5, labelpad=40, fontsize = 16)

ax.set_xlabel("Longitude (°)")
ax.set_ylabel("Latitude (°)")

rect = patches.Rectangle((-88, 26.5), 1.25, 1, linewidth=2, edgecolor='k', facecolor='none')
ax.add_patch(rect)
ax.text(-87.9, 27.25, "B", fontsize=24, c = "k")

rect = patches.Rectangle((-89, 27.75), 1.25, 1.25, linewidth=2, edgecolor='k', facecolor='none')
ax.add_patch(rect)
ax.text(-87.95, 27.8, "A", fontsize=24, c = "k")

plt.show()

# %% [markdown]
# ## Parameters for vortex extraction

# %%
from ipynb.fs.defs.extract_vortex import __extract_vortex__

threshold = .5
threshold_loc_max = .7
N_drifters = 4

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize = (16, 7.6), constrained_layout=True)
ax = []
idx_list = [0, 2*96, 4*96, 6*96, 7*96] # [2days, 2days, 2days, 1day]
idx_x = [0, 1, 0, 1, 1]
idx_y = [0, 0, 1, 1, 0]
counter = 0

# Define limits of plot
x_limits = [-89.2, -86]
y_limits = [26.2, 28]

delta_x = x_limits[1]-x_limits[0]
delta_y = y_limits[1]-y_limits[0]

x_min = x_limits[0]
x_max = x_limits[1]
y_min = y_limits[0]
y_max = y_limits[1]

# Create 2x2 sub plots
gs = gridspec.GridSpec(2, 3, width_ratios = [delta_x, delta_x, 2*delta_x], height_ratios = [delta_y, delta_y])

ID_vortex = []

date = datetime(2012, 8, 10, 0, 0, 0)
date_final = datetime(2012, 8, 17, 0, 0, 0)

for idx in idx_list:
    
    filesave = r'/Users/enalex/OneDrive/Draft_Drifter_TRA/TRA_drifter_evolution_GLAD.jpg'
    
    TRA, long, lat = [], [], []
    long_final, lat_final = [], []
    
    # time
    time = d[0][:idx+1]
    
    for d in drifters:
        #longitudinal position of drifter d
        longitude_total = d[1].copy()
        longitude = d[1][:idx+1].copy()
        # latitudinal position of drifter d
        latitude_total = d[2].copy()
        latitude = d[2][:idx+1].copy()
        # TRA associated to drifter d over the time d[0][:idx+1]
        print(len(longitude))
        f = 96
        TRA.append(__TRA__(longitude_total, latitude_total , time, f))
        print(TRA)
        # Append longitude/latitude
        long.append(longitude)
        lat.append(latitude)
        # store final position
        long_final.append(longitude[idx])
        lat_final.append(latitude[idx])
    
    print(TRA)
    
    # scattered linear rbf-interpolation at time[idx]
    X, Y, TRA_rbf = rbf(long_final, lat_final, TRA, res_interpolation)

    long_vortex, lat_vortex = __extract_vortex__(TRA_rbf, X, Y, long_final, lat_final, res_interpolation, threshold, threshold_loc_max, N_drifters)

    #ROTATION = distance_to_source(X, Y, x_scatter.copy(), y_scatter.copy(), ROTATION)

    TRA_max = 1.5 # np.around(np.nanmax(ROTATION), 2)
    TRA_min = 0.3 # np.around(np.nanmin(ROTATION), 2)

    yearday = (datetime.strptime(time[idx], '%Y-%m-%d %H:%M:%S') - datetime(2012, 1, 1, 0, 0, 0)).total_seconds() / (3600 * 24)

    print(yearday)
# Out:
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-db964832cd90> in <module>
#      48         print(len(longitude))
#      49         f = 96
# ---> 50         TRA.append(__TRA__(longitude_total, latitude_total , time, f))
#      51         print(TRA)
#      52         # Append longitude/latitude
#
# ~/OneDrive/Documents/GitHub/Quasi-objective-eddy-visualization/src/TRA.ipynb in __TRA__(longitude, latitude, time, f, v0)
#      19     "import great_circle_calculator.great_circle_calculator as gcc\n",
#      20     "\n",
# ---> 21     "def __TRA__(longitude, latitude, time, f, v0=10**(-5)):\n",
#      22     "    \n",
#      23     "    # compute velocity from finite-differencing\n",
#
# IndexError: list index out of range
